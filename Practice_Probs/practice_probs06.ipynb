# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(np.e)
# Out:
# 2.718281828459045

# %%
# %matplotlib inline

# %%
thetas_in_degrees = range(0,360,5)
thetas_in_radians = np.radians(thetas_in_degrees)

tans = np.tan(thetas_in_radians)
tans
# Out:
# array([ 0.00000000e+00,  8.74886635e-02,  1.76326981e-01,  2.67949192e-01,
#         3.63970234e-01,  4.66307658e-01,  5.77350269e-01,  7.00207538e-01,
#         8.39099631e-01,  1.00000000e+00,  1.19175359e+00,  1.42814801e+00,
#         1.73205081e+00,  2.14450692e+00,  2.74747742e+00,  3.73205081e+00,
#         5.67128182e+00,  1.14300523e+01,  1.63312394e+16, -1.14300523e+01,
#        -5.67128182e+00, -3.73205081e+00, -2.74747742e+00, -2.14450692e+00,
#        -1.73205081e+00, -1.42814801e+00, -1.19175359e+00, -1.00000000e+00,
#        -8.39099631e-01, -7.00207538e-01, -5.77350269e-01, -4.66307658e-01,
#        -3.63970234e-01, -2.67949192e-01, -1.76326981e-01, -8.74886635e-02,
#        -1.22464680e-16,  8.74886635e-02,  1.76326981e-01,  2.67949192e-01,
#         3.63970234e-01,  4.66307658e-01,  5.77350269e-01,  7.00207538e-01,
#         8.39099631e-01,  1.00000000e+00,  1.19175359e+00,  1.42814801e+00,
# ...

# %%
plt.plot(thetas_in_radians, tans, color='g', linestyle = 'dashdot', linewidth = 5, label='Tangent', )
plt.xlabel('Angles (radians)')
plt.ylabel('Tangents')
plt.ylim(-1,1)
plt.title('Plot of Tangents')
plt.legend()
plt.show()

# %%
rain_fall = np.loadtxt('../Datasets/rainFall/avg_rain.txt')
# print(type(rain_fall))
# print(rain_fall)

years = np.array(range(1931,2017))
#print(years)

plt.bar(years, rain_fall)
plt.xlabel('Years')
plt.ylabel('Inches')
plt.title('Yearly Average Rainfall')
plt.show()

# %%
plt.plot(years, rain_fall, marker = 'o', markerfacecolor = 'r')
plt.xlabel('Years')
plt.ylabel('Inches')
plt.title('Yearly Average Rainfall')
plt.show()
